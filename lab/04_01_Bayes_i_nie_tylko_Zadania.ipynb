# %% [markdown]
# ## Zadanie 1
#
# Wykonujemy rzuty pewną symetryczną monetą. Na 95% moneta jest normalna, na 5% są na niej dwa orły.
#
# Ile razy musi wypaść orzeł, aby w kolejnym rzucie prawdopodobieństwo wypadnięcia orła przekroczyło 50%?
#
# Ile razy musi wypaść orzeł, aby przekroczyło ono 95%?
#
# Jak wygląda posterior, jeśli w siedemnastym rzucie pierwszy raz wypadnie reszka?
#
# ## Zadanie 2
#
# Rzucamy kostką sześcienną. Na 80% kostka jest symetryczna, na 20% jest ważona i szóstka wypada z prawdopodobieństwem 3/8, a pozostałe liczby z prawdopodobieństwem 1/8. W trzech rzutach wypadły kolejno: liczba parzysta, liczba pierwsza, szóstka.
#
# Policzyć MLE i MAP dla hipotez.
#
# Policzyć PPD dla czwartego rzutu kością.
#
# ## Zadanie 3
#
# Kiedy obserwacja nie daje nam żadnej nowej informacji? Zdefiniować "nie daje nowej informacji" w języku prior/likelihood/posterior.
#
# ## Zadanie 4
#
# Rozważmy dwie sytuacje:
# 1. Badamy monetę (jak w zadaniu pierwszym). Wynik czterech kolejnych rzutów to: orzeł, orzeł, moneta upadła na kant, reszka.
# 2. Badamy symetryczność kostki (jak w zadaniu drugim). Wynik czterech kolejnych rzutów to: 1, 4, 3, orzeł.
#
# Jak wygląda posterior w obu przypadkach?
#
# Czy mamy prawo usuwać "bezsensowne" obserwacje?
#
# Czy istnieje prior, który pozwala "usuwać" "bezsensowne" obserwacje?
#
# ## Zadanie 5
#
# Mamy dwóch pacjentów i jedną dawkę lekarstwa na pewną chorobę. Pacjent pierwszy pochodzi z grupy podwyższonego ryzyka - szansa, że jest chory wynosi 50%. Pacjent drugi jest chory na 5%. Możemy badać pacjentów, ale metoda diagnostyczna jest bardzo niedokładna - z prawdopodobieństwem 30% wynik będzie błędny. Zbadaliśmy pierwszego pacjenta, wynik: zdrowy. Dwukrotnie zbadaliśmy drugiego pacjenta i dwukrotnie otrzymaliśmy wynik: chory.
#
# Komu powinniśmy podać lekarstwo?
#
# ## Zadanie 6
#
# Ile minimalnie badań musimy wykonać w zadaniu 5, aby w ogóle był sens je wykonywać? Dlaczego?
#
# ## Zadanie 7
#
# Konkurs: mamy 3 pudełka, w jednym z nich jest nagroda, pozostałe są puste. Wybieramy jedno pudełko. Prowadzący konkurs otwiera jedno z dwóch pozostałych pudełek, o którym on wie, że jest puste.
#
# Czy opłaca się nam zmienić pudełko na drugie nieotwarte?
#
# ## Zadanie 8
#
# Konkurs: mamy 3 pudełka, w jednym z nich jest nagroda, pozostałe są puste. Wybieramy jedno pudełko. Prowadzący konkurs otwiera losowo jedno z dwóch pozostałych pudełek i okazuje się, że jest ono puste.
#
# Czy opłaca się nam zmienić pudełko na drugie nieotwarte?
#
# ## Zadanie 9
#
# Gracz A losuje pary liczb z pewnego znanego tylko jemu ciągłego rozkładu prawdopodobieństwa na prostej $\mathbb{R}$. Gracz B wybiera i odczytuje jedną z tych liczb, a następnie musi zgadnąć, czy druga jest większa czy mniejsza. Zaproponuj strategię uczenia, która pomoże graczowi B jak najczęściej zgadywać poprawnie (rozkład prawdopodobieństwa gracza A nie zmienia się w kolejnych rundach).
#
# ## Zadanie 10
#
# Gracz A losuje pary liczb z pewnego znanego tylko sobie ciągłego rozkładu prawdopodobieństwa na prostej $\mathbb{R}$. Gracz B wybiera i odczytuje jedną z tych liczb, a następnie musi zgadnąć, czy druga jest większa czy mniejsza. Zaproponuj strategię, która już __za pierwszym razem__ daje prawdopodobieństwo zgadnięcia silnie większe od 50%.
